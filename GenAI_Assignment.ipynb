# %% [markdown]
# # Mini Prompt Engine using LangChain

# %% [markdown]
# ## Task 1: Replace Hardcoded Prompts

# %%
# !pip install langchain
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain
#   Downloading langchain-1.2.16-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-core<2.0.0,>=1.3.2 (from langchain)
#   Downloading langchain_core-1.3.2-py3-none-any.whl.metadata (4.4 kB)
# Collecting langgraph<1.2.0,>=1.1.10 (from langchain)
#   Downloading langgraph-1.1.10-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\programdata\anaconda3\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain) (1.33)
# Collecting langchain-protocol>=0.0.10 (from langchain-core<2.0.0,>=1.3.2->langchain)
#   Downloading langchain_protocol-0.0.14-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.3.2->langchain)
#   Downloading langsmith-0.7.38-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.3.2->langchain)
#   Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.2->langchain) (3.0.0)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.2.0,>=1.1.10->langchain)
#   Downloading langgraph_checkpoint-4.0.3-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.12 (from langgraph<1.2.0,>=1.1.10->langchain)
#   Downloading langgraph_prebuilt-1.0.13-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.2.0,>=1.1.10->langchain)
#   Downloading langgraph_sdk-0.3.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.2.0,>=1.1.10->langchain)
#   Downloading xxhash-3.7.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.10->langchain)
#   Downloading ormsgpack-1.12.2-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: httpx>=0.25.2 in c:\programdata\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (0.28.1)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain)
#   Downloading orjson-3.11.8-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain) (0.24.0)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (4.10.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (1.3.0)
# Downloading langchain-1.2.16-py3-none-any.whl (112 kB)
# Downloading langchain_core-1.3.2-py3-none-any.whl (542 kB)
#    ---------------------------------------- 0.0/542.4 kB ? eta -:--:--
#    ---------------------------------------- 542.4/542.4 kB 8.4 MB/s  0:00:00
# Downloading langgraph-1.1.10-py3-none-any.whl (173 kB)
# Downloading langgraph_checkpoint-4.0.3-py3-none-any.whl (51 kB)
# Downloading langgraph_prebuilt-1.0.13-py3-none-any.whl (37 kB)
# Downloading langgraph_sdk-0.3.13-py3-none-any.whl (96 kB)
# Downloading langsmith-0.7.38-py3-none-any.whl (392 kB)
# Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl (187 kB)
# Downloading langchain_protocol-0.0.14-py3-none-any.whl (7.0 kB)
# Downloading orjson-3.11.8-cp313-cp313-win_amd64.whl (127 kB)
# Downloading ormsgpack-1.12.2-cp313-cp313-win_amd64.whl (117 kB)
# Downloading xxhash-3.7.0-cp313-cp313-win_amd64.whl (31 kB)
# Installing collected packages: xxhash, uuid-utils, ormsgpack, orjson, langchain-protocol, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#    ---------- -----------------------------  3/12 [orjson]
#    ---------------- -----------------------  5/12 [langsmith]
#    ---------------- -----------------------  5/12 [langsmith]
#    ---------------- -----------------------  5/12 [langsmith]
#    ---------------- -----------------------  5/12 [langsmith]
#    ---------------- -----------------------  5/12 [langsmith]
#    ---------------- -----------------------  5/12 [langsmith]
#    ---------------- -----------------------  5/12 [langsmith]
#    ---------------- -----------------------  5/12 [langsmith]
#    -------------------- -------------------  6/12 [langgraph-sdk]
#    -------------------- -------------------  6/12 [langgraph-sdk]
#    ----------------------- ----------------  7/12 [langchain-core]
#    ----------------------- ----------------  7/12 [langchain-core]
#    ----------------------- ----------------  7/12 [langchain-core]
#    ----------------------- ----------------  7/12 [langchain-core]
#    ----------------------- ----------------  7/12 [langchain-core]
#    ----------------------- ----------------  7/12 [langchain-core]
#    ----------------------- ----------------  7/12 [langchain-core]
#    ----------------------- ----------------  7/12 [langchain-core]
#    ----------------------- ----------------  7/12 [langchain-core]
#    ----------------------- ----------------  7/12 [langchain-core]
#    ----------------------- ----------------  7/12 [langchain-core]
#    ----------------------- ----------------  7/12 [langchain-core]
#    ----------------------- ----------------  7/12 [langchain-core]
#    ----------------------- ----------------  7/12 [langchain-core]
#    ----------------------- ----------------  7/12 [langchain-core]
#    -------------------------- -------------  8/12 [langgraph-checkpoint]
#    ------------------------------ ---------  9/12 [langgraph-prebuilt]
#    --------------------------------- ------ 10/12 [langgraph]
#    --------------------------------- ------ 10/12 [langgraph]
#    --------------------------------- ------ 10/12 [langgraph]
#    --------------------------------- ------ 10/12 [langgraph]
#    ------------------------------------ --- 11/12 [langchain]
#    ------------------------------------ --- 11/12 [langchain]
#    ------------------------------------ --- 11/12 [langchain]
#    ---------------------------------------- 12/12 [langchain]
#
# Successfully installed langchain-1.2.16 langchain-core-1.3.2 langchain-protocol-0.0.14 langgraph-1.1.10 langgraph-checkpoint-4.0.3 langgraph-prebuilt-1.0.13 langgraph-sdk-0.3.13 langsmith-0.7.38 orjson-3.11.8 ormsgpack-1.12.2 uuid-utils-0.14.1 xxhash-3.7.0

# %%
from langchain_core.prompts import PromptTemplate

# Create reusable template
explain_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)

print(explain_template.format(topic="AI"))
# Out:
# Explain AI in simple terms for beginners

# %% [markdown]
# ## Task 2: Multi-Input Prompt System

# %%
multi_input_template = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

# Test cases
print(multi_input_template.format(topic="AI", audience="beginners", tone="friendly"))
print(multi_input_template.format(topic="Python", audience="kids", tone="fun"))
print(multi_input_template.format(topic="Deep Learning", audience="engineers", tone="technical"))
# Out:
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Deep Learning for engineers in a technical tone

# %% [markdown]
# ## Task 3: Prompt Variations Engine

# %%
teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 interview questions about {topic}"
)

story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

topic = "Machine Learning"

print(teaching_template.format(topic=topic))
print(interview_template.format(topic=topic))
print(story_template.format(topic=topic))
# Out:
# Explain Machine Learning clearly step by step
# Ask 3 interview questions about Machine Learning
# Explain Machine Learning as a story

# %% [markdown]
# ## Task 4: ChatPromptTemplate System

# %%
from langchain_core.prompts import ChatPromptTemplate
def get_chat_prompt(role, topic):
    
    if role == "teacher":
        system_msg = "You are a helpful teacher."
    elif role == "interviewer":
        system_msg = "You are a strict interviewer."
    elif role == "motivator":
        system_msg = "You are an inspiring motivator."
    else:
        system_msg = "You are a helpful assistant."

    chat_template = ChatPromptTemplate.from_messages([
        ("system", system_msg),
        ("user", "Talk about {topic}")
    ])

    return chat_template.format_messages(topic=topic)

# Test
messages = get_chat_prompt("teacher", "Neural Networks")
print(messages)
# Out:
# [SystemMessage(content='You are a helpful teacher.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Talk about Neural Networks', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ## Task 5: Input Validation Layer

# %%
def validate_inputs(audience, tone):
    
    valid_audience = ["beginner", "intermediate", "expert"]
    valid_tone = ["formal", "casual", "fun"]

    if audience not in valid_audience:
        audience = "beginner"

    if tone not in valid_tone:
        tone = "formal"

    return audience, tone

# Test
print(validate_inputs("kids", "cool"))  # fallback to defaults
# Out:
# ('beginner', 'formal')

# %% [markdown]
# ## Task 6: Prompt Generator App

# %%
def generate_prompt(topic, audience, tone, style):

    audience, tone = validate_inputs(audience, tone)

    if style == "teaching":
        template = PromptTemplate(
            input_variables=["topic", "audience", "tone"],
            template="Explain {topic} for {audience} in a {tone} teaching style"
        )

    elif style == "interview":
        template = PromptTemplate(
            input_variables=["topic"],
            template="Ask interview questions about {topic}"
        )

    elif style == "storytelling":
        template = PromptTemplate(
            input_variables=["topic", "audience", "tone"],
            template="Explain {topic} for {audience} in a {tone} storytelling style"
        )

    else:
        template = PromptTemplate(
            input_variables=["topic"],
            template="Explain {topic}"
        )

    return template.format(topic=topic, audience=audience, tone=tone)

# Test
print(generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))
# Out:
# Explain Neural Networks for beginner in a fun storytelling style

# %% [markdown]
# ## Task 7: Template Reusability Test

# %%
reuse_template = PromptTemplate(
    input_variables=["topic", "audience"],
    template="Explain {topic} for {audience}"
)

inputs = [
    ("AI", "beginners"),
    ("Python", "kids"),
    ("Data Science", "students"),
    ("Cloud Computing", "engineers"),
    ("Cyber Security", "analysts")
]

for topic, audience in inputs:
    print(reuse_template.format(topic=topic, audience=audience))
# Out:
# Explain AI for beginners
# Explain Python for kids
# Explain Data Science for students
# Explain Cloud Computing for engineers
# Explain Cyber Security for analysts
